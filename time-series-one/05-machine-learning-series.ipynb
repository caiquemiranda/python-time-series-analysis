# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d = pd.read_csv('./data/AirPassengers.csv',
                header=0,
                parse_dates=[0],
                index_col=0,
                squeeze=True)
d.head(3)
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# Name: #Passengers, dtype: int64

# %%
diff = d.diff(12)
diff.head(13)
# Out:
# Month
# 1949-01-01    NaN
# 1949-02-01    NaN
# 1949-03-01    NaN
# 1949-04-01    NaN
# 1949-05-01    NaN
# 1949-06-01    NaN
# 1949-07-01    NaN
# 1949-08-01    NaN
# 1949-09-01    NaN
# 1949-10-01    NaN
# 1949-11-01    NaN
# 1949-12-01    NaN
# 1950-01-01    3.0
# Name: #Passengers, dtype: float64

# %%
# visualização dos dados
diff.plot()
plt.show();

# %%
# remoção dos primeiros registros (12)[:]

diff = diff[12:]
diff
# Out:
# Month
# 1950-01-01     3.0
# 1950-02-01     8.0
# 1950-03-01     9.0
# 1950-04-01     6.0
# 1950-05-01     4.0
#               ...
# 1960-08-01    47.0
# 1960-09-01    45.0
# 1960-10-01    54.0
# 1960-11-01    28.0
# 1960-12-01    27.0
# Name: #Passengers, Length: 132, dtype: float64

# %%
# visualização dos dados

diff.plot()
plt.show();
